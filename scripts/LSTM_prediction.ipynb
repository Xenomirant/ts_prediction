# %%
import torch
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/featurized_dataset.csv")

# %%
timeseries = data.Balance

# %%
full_data = pd.read_excel("data/Project 1_2024.xlsx")

# %%
timeseries = full_data[["Balance"]].values.astype("float32")

# %%
# train-test split for time series
train_size = int(len(timeseries) * 0.8)
test_size = len(timeseries) - train_size
train, test = timeseries[:train_size], timeseries[train_size:]

# %%
def create_dataset(dataset, lookback):
    """Transform a time series into a prediction dataset

    Args:
        dataset: A numpy array of time series, first dimension is the time steps
        lookback: Size of window for prediction
    """
    X, y = [], []
    for i in range(len(dataset)-lookback):
        feature = dataset[i:i+lookback]
        target = dataset[i+1:i+lookback+1]
        X.append(feature)
        y.append(target)
    return torch.tensor(X), torch.tensor(y)

# %%
lookback = 15
X_train, y_train = create_dataset(train, lookback=lookback)
X_test, y_test = create_dataset(test, lookback=lookback)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([1219, 15, 1]) torch.Size([1219, 15, 1])
# torch.Size([294, 15, 1]) torch.Size([294, 15, 1])
# C:\Users\il.pugin\AppData\Local\Temp\ipykernel_14208\844590115.py:14: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:278.)
#   return torch.tensor(X), torch.tensor(y)

# %%
import torch.nn as nn

class AirModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=32, num_layers=2, batch_first=True, dropout=0.4)
        self.linear = nn.Linear(32, 1)
    def forward(self, x, debug = False):
        x, _ = self.lstm(x)
        if debug:
          print(x.shape)

        x = self.linear(x)
        return x

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
len(X_train)
# Out:
# 1219

# %% [markdown]
# Будем считать градиенты по всему батчу -- с одной стороны это позволяет сделать спуск именно спуском, с другой стороны, благодаря дисперсии градиента при стохастике, можно получить лучшую генерализуемость на тесте -- в целом надо и так и так экспериментировать

# %%
import torch.optim as optim
import torch.utils.data as data

model = AirModel().to(device)
optimizer = optim.Adam(model.parameters())
loss_fn = nn.MSELoss()
loader = data.DataLoader(data.TensorDataset(X_train, y_train),
                         batch_size=1203, drop_last=True)

n_epochs = 5000
for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in loader:
        y_pred = model(X_batch.to(device), debug=False)
        loss = loss_fn(y_pred, y_batch.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Validation
    if epoch % 100 != 0:
        continue
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train.to(device))
        train_mae = torch.max(np.abs(y_pred.cpu()[:, -1, :] - y_train[:, -1, :]), dim=0)[0].item()
        y_pred = model(X_test.to(device))
        test_mae = torch.max(np.abs(y_pred.cpu()[:, -1, :] - y_test[:, -1, :]), dim=0)[0].item()
    print("Epoch %d: train MAXAE %.4f, test MAXAE %.4f" % (epoch, train_mae, test_mae))
# Out:
# Epoch 0: train MAXAE 2.3826, test MAXAE 2.5186
# Epoch 100: train MAXAE 2.3655, test MAXAE 2.2768
# Epoch 200: train MAXAE 2.2815, test MAXAE 2.2015
# Epoch 300: train MAXAE 2.2225, test MAXAE 2.2862
# Epoch 400: train MAXAE 1.9258, test MAXAE 2.3072
# Epoch 500: train MAXAE 1.3536, test MAXAE 2.2902
# Epoch 600: train MAXAE 1.2775, test MAXAE 2.2628
# Epoch 700: train MAXAE 1.2075, test MAXAE 2.2889
# Epoch 800: train MAXAE 1.1232, test MAXAE 2.3316
# Epoch 900: train MAXAE 0.9888, test MAXAE 2.3289
# Epoch 1000: train MAXAE 0.8509, test MAXAE 2.3149
# Epoch 1100: train MAXAE 0.8037, test MAXAE 2.3065
# Epoch 1200: train MAXAE 0.7464, test MAXAE 2.3205
# Epoch 1300: train MAXAE 0.6981, test MAXAE 2.3383
# Epoch 1400: train MAXAE 0.6427, test MAXAE 2.3157
# Epoch 1500: train MAXAE 0.5814, test MAXAE 2.3157
# Epoch 1600: train MAXAE 0.5447, test MAXAE 2.3060
# Epoch 1700: train MAXAE 0.5207, test MAXAE 2.2895
# Epoch 1800: train MAXAE 0.4637, test MAXAE 2.2641
# Epoch 1900: train MAXAE 0.4613, test MAXAE 2.2667
# Epoch 2000: train MAXAE 0.4522, test MAXAE 2.2699
# Epoch 2100: train MAXAE 0.4598, test MAXAE 2.2752
# Epoch 2200: train MAXAE 0.4680, test MAXAE 2.2747
# Epoch 2300: train MAXAE 0.4882, test MAXAE 2.2723
# Epoch 2400: train MAXAE 0.4700, test MAXAE 2.2780
# Epoch 2500: train MAXAE 0.5327, test MAXAE 2.2757
# Epoch 2600: train MAXAE 0.4540, test MAXAE 2.2858
# Epoch 2700: train MAXAE 0.4795, test MAXAE 2.2785
# Epoch 2800: train MAXAE 0.4944, test MAXAE 2.2806
# Epoch 2900: train MAXAE 0.4338, test MAXAE 2.2724
# Epoch 3000: train MAXAE 0.4383, test MAXAE 2.2769
# Epoch 3100: train MAXAE 0.4213, test MAXAE 2.2938
# Epoch 3200: train MAXAE 0.4402, test MAXAE 2.2864
# Epoch 3300: train MAXAE 0.4508, test MAXAE 2.2812
# Epoch 3400: train MAXAE 0.4475, test MAXAE 2.2725
# Epoch 3500: train MAXAE 0.4633, test MAXAE 2.2741
# Epoch 3600: train MAXAE 0.4888, test MAXAE 2.2847
# Epoch 3700: train MAXAE 0.4790, test MAXAE 2.2922
# Epoch 3800: train MAXAE 0.4602, test MAXAE 2.2794
# Epoch 3900: train MAXAE 0.4799, test MAXAE 2.2707
# Epoch 4000: train MAXAE 0.4829, test MAXAE 2.2819
# Epoch 4100: train MAXAE 0.4764, test MAXAE 2.2791
# Epoch 4200: train MAXAE 0.4520, test MAXAE 2.2711
# Epoch 4300: train MAXAE 0.4599, test MAXAE 2.2703
# Epoch 4400: train MAXAE 0.4525, test MAXAE 2.2637
# Epoch 4500: train MAXAE 0.4899, test MAXAE 2.2656
# Epoch 4600: train MAXAE 0.4802, test MAXAE 2.2647
# Epoch 4700: train MAXAE 0.4774, test MAXAE 2.2535
# Epoch 4800: train MAXAE 0.4966, test MAXAE 2.2501
# Epoch 4900: train MAXAE 0.4674, test MAXAE 2.2535

# %%
from matplotlib import pyplot as plt

model.to("cpu")

with torch.no_grad():
    # shift train predictions for plotting
    train_plot = np.ones_like(timeseries) * np.nan
    train_plot[lookback:train_size] = model(X_train)[:, -1, :]
    # shift test predictions for plotting
    test_plot = np.ones_like(timeseries) * np.nan
    test_plot[train_size+lookback:len(timeseries)] = model(X_test)[:, -1, :]
# plot
plt.figure(figsize=(12, 6))
plt.plot(timeseries, c='b', label="Ground truth",)
plt.plot(train_plot, c='r', label="Training", alpha=0.6)
plt.plot(test_plot, c='g', label="Testing", alpha=0.6)
plt.legend()
plt.show()

# %%
with torch.no_grad():
    # shift train predictions for plotting
    train_plot = np.zeros_like(timeseries)
    train_plot[lookback:train_size] = model(X_train)[:, -1, :]
    # shift test predictions for plotting
    test_plot = np.zeros_like(timeseries)
    test_plot[train_size+lookback:len(timeseries)] = model(X_test)[:, -1, :]

plt.plot(timeseries - train_plot - test_plot, c='b', label="Error")
plt.hlines(y = [-0.42, 0.42], xmin=0, xmax=len(timeseries))
plt.legend()
plt.show()

# %%
import pickle

# %%
# Save the model to a file
model_file_path = 'model/lstm_model.pkl'
pickle.dump(model, open(model_file_path, 'wb'))
